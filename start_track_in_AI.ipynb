# %% [markdown]
# # 2 Часть 1. Знакомство с Python

# %% [markdown]
# ## 2.1  Язык Python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## 2.2  Переменные и арифметические действия

# %%
a = 5
print(id(a))
# Out:
# 11645480

# %%
-7 // 3
# Out:
# -3

# %%
-7 % 3
# Out:
# 2

# %%
result = var1 * 2 + var2 * 3 + \
            var3 * 4 + var4 * 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1324/2008092346.py in <cell line: 0>()
# ----> 1 result = var1 * 2 + var2 * 3 + \
#       2             var3 * 4 + var4 * 5
#
# NameError: name 'var1' is not defined

# %% [markdown]
# ## 2.3  Типы данных

# %%
print(type(5))

a = 1.5
print(type(a))

passed = True
print(type(passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a = int(input('Введите первое число'))
b = int(input('Введите второе число'))
sum = a + b
print('a + b = ', sum)
# Out:
# Введите первое число1
# Введите второе число2
# a + b =  3

# %%
a = 1_000_000
b = 0b_1111_0001
c = 0x_1234_abcd
print(a)
print(b)
print(c)
# Out:
# 1000000
# 241
# 305441741

# %%
import math

print(math.sqrt(16))
# Out:
# 4.0

# %%
print(2/3)
# Out:
# 0.6666666666666666

# %%
print(format(12345.6789, '.2f')) # результат 12345.68
print(format(12345.6789, '.1f')) # результат 12345.7
# Out:
# 12345.68
# 12345.7

# %%
print('''
Я помню чудное мгновенье:
Передо мной явилась ты,
Как мимолетное виденье,
Как гений чистой красоты.
''')
# Out:
# Я помню чудное мгновенье:
# Передо мной явилась ты,
# Как мимолетное виденье,
# Как гений чистой красоты.

# %%
s1 = '12'
s2 = '34'
print(s1 + s2)
print(s2 + s1)
# Out:
# 1234
# 3412

# %%
s = 'ʕ ᵔᴥᵔ ʔ' *10
print(s)
# Out:
# ʕ ᵔᴥᵔ ʔʕ ᵔᴥᵔ ʔʕ ᵔᴥᵔ ʔʕ ᵔᴥᵔ ʔʕ ᵔᴥᵔ ʔʕ ᵔᴥᵔ ʔʕ ᵔᴥᵔ ʔʕ ᵔᴥᵔ ʔʕ ᵔᴥᵔ ʔʕ ᵔᴥᵔ ʔ

# %%
s = 'Python'
print(len(s))
print(len('Hello'))
# Out:
# 6
# 5

# %%
s1 = str(123)    #получаем строку '123'
s2 = str(123.45) #получаем строку '123.45'

# %%
print(bool(1))        #True
print(bool(-1.0))     #True
print(bool(0))        #False
print(bool('Python')) #True
print(bool(''))       #False
# Out:
# True
# True
# False
# True
# False

# %% [markdown]
# ### Дележ яблок-1

# %%
N = int(input())
K = int(input())

result_2_3_1 = K // N
print(result_2_3_1)
# Out:
# 3
# 14
# 4

# %% [markdown]
# ### Дележ яблок-2

# %%
N = int(input())
K = int(input())

result_2_3_2 = K % N
print(result_2_3_2)
# Out:
# 3
# 14
# 2

# %% [markdown]
# ### Последняя цифра

# %%
n = int(input())

result_2_3_3 = n % 10
print(result_2_3_3)
# Out:
# 179
# 9

# %%
112 % 10
# Out:
# 2
